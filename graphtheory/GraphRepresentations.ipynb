# %% [markdown]
# # Graph Representations

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ##Adjacency List

# %% [markdown]
# ### Undirected

# %% [markdown]
# ### Directed, weighted

# %% [markdown]
# ##Adjacency Matrix

# %% [markdown]
# ### Undirected

# %% [markdown]
# ### Directed, weighted
